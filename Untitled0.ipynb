# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego09DG/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** ❎ ♦ ⏺

# %%
ano = "II"
print(ano, "I competição de programação dá Start")
# Out:
# I competição de programação dá Start

# %% [markdown]
# #**Aula 2** ✈ ▶ ❌

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_ana}")
print(f"Os pontos totais são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais são 70

# %% [markdown]
# #**aula 3** ✒ ⚫ ⬛

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao2 = 2 * figurinhas_amigo
figurinhas_extras = int(input("Digite o número de figurinhas extras: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)
figurinhas_extras = figurinhas_extras * 2

print(f"João recebeu {figurinhas_joao} figurinhas")
print(f"João recebeu {figurinhas_joao2} figurinhas extras")

# %% [markdown]
# #**Aula 4** ♾ ♎ ✅
#
# #dia de prova

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 23
# Digite a posição da porta R (0 ou 1): 23
# B

# %% [markdown]
# #**Aula 5**  - calculo de IMC 🐺 🐹 👽

# %%
peso = float(input("Digite seu peso (em kg): "))
altura_str = input("Digite sua altura (em metros): ")
altura = float(altura_str.replace(',', '.'))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 68
# Digite sua altura (em metros): 1.78
#
# Seu IMC é: 21.46
# Você está no peso ideal.

# %% [markdown]
# ##**Aula 6** Tabuada ✔ ❤ ♦

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 24
# 24 x 1 = 24
# 24 x 2 = 48
# 24 x 3 = 72
# 24 x 4 = 96
# 24 x 5 = 120
# 24 x 6 = 144
# 24 x 7 = 168
# 24 x 8 = 192
# 24 x 9 = 216
# 24 x 10 = 240

# %% [markdown]
# #**Aula 7 idade**❗ ❕ ‼

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima
resultado = calcula_idade_maior(68, 12, 30)
print(resultado)
# Out:
# (26, 30)

# %% [markdown]
# **Aula 9** Listas ♟ ☕ 🥉

# %%
import random
 dica = [
"Acredite no seu potencial 🚀",
"Você é capaz de superar qualquer desafio 💪",
"Cada dia é uma nova chance de recomeçar 🌅",
"Foque no que te faz crescer 🌱",
"Sua determinação te leva longe 🏆",
"Continue mesmo quando for difícil 🔥",
"A disciplina constrói resultados sólidos 🧱",
"Pequenos passos criam grandes jornadas 🛤️",
"O sucesso começa com uma atitude positiva 😊",
"Confie no processo e siga em frente ➡️",
]
    while True:
  pedido = input("Digite'dica' para receber uma dica ou 'sair' para encarrar"). lower()

    if pedido == "dica":
    dica = random.choice(dicar) # escolher uma dica aleatória

      print(f"Dica:{dica}")
    elif pedido == "sair":
      print("Até mais")
      break
    else:
      print("Comando não reconhecido. Tente novamente.")
# Out:
#   File "/tmp/ipython-input-3793629787.py", line 2
#     dica = [
#     ^
# IndentationError: unexpected indent
